# %%
pip install numpy pandas scipy yfinance arch matplotlib seaborn plotly pytest jupyter
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 942.6/942.6 kB 3.0 MB/s eta 0:00:0000:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Out:
#   Cell In[2], line 1
#     mkdir vol-surface-project
#           ^
# SyntaxError: invalid syntax
